# %% [markdown]
# # Memory Reduction of our datasets
#
# This notebook process both train and test dataframes downcasting the data types, allowing to work them safely in kaggle without running out of the assigned RAM memory. Also exports these files to binary, in order to speed their load in subsequent uses.
#
# > For this task, we use the function created by Alexey Kupershtokh (https://www.kaggle.com/alexeykupershtokh/safe-memory-reduction)

# %%
import numpy as np 
import pandas as pd
from memory_reduction_script import reduce_mem_usage_sd as mr # we are using the memory reduction by our utility script

# %% [markdown]
# ### This script will perform the following tasks:
#
# * Creates the columns `DT`: the `TransactionDT` (Delta time) from seconds to days.
# * Creates the columns `Dxachr` referenced to the `DT` Delta days. These columns are days from a specific date or point in the past, so substracting the days passed since the begining of the dataset (`DT`), we can get that specific "date" delta.
#
# We initially were not intended to work with test data, and we were partitioning or own test data from train for our final bootcamp project purposes.
# **Finally we decide to use full train for train and validation and test with test file, submitting the results to kaggle as we were participating in the competition.**

# %%
##### Download of files.

print('Downloading datasets...')
print(' ')
train = pd.read_csv('/kaggle/input/ieee-fraud-detection/train_transaction.csv')
print('Train has been downloaded... (1/2)')
test = pd.read_csv('/kaggle/input/ieee-fraud-detection/test_transaction.csv')
print('Test has been downloaded... (2/2)')
print('Done!')
# Out:
# Downloading datasets...
#
# Train has been downloaded... (1/2)
# Test has been downloaded... (2/2)
# Done!

# %%
##### Transforming the columns D en Dxachr (D anchored).
# D1, D2, D4, D6, D10, D11 - D15.
# D3, D5, D7 are differences between a transaction of a card and his previous one. Does not have sense to do the same thing.
# D8, D9 are probably hr. We keep them untouched.

train['DT'] = np.floor(train.TransactionDT/(60*60*24))
test['DT']  = np.floor(test.TransactionDT/(60*60*24))

columns_D = ['D' + str(i) for i in range(1,16) if i not in [3, 5, 7, 8, 9]]

for col in columns_D:
    train[col+'achr'] = train['DT'] - train[col]
    test[col+'achr']  = test['DT']  - test[col]

# %%
##### Reducing memory with safe downcast function.

train = mr(train, verbose=True)
test  = mr(test, verbose=True)
# Out:
# Column TransactionID: int64 -> int32, na_count=0, n_uniq=590540
# Column isFraud: int64 -> int8, na_count=0, n_uniq=2
# Column TransactionDT: int64 -> int32, na_count=0, n_uniq=573349
# Column TransactionAmt: float64 -> float32, na_count=0, n_uniq=20902
# Column ProductCD: object -> object, na_count=0, n_uniq=5
# Column card1: int64 -> int16, na_count=0, n_uniq=13553
# Column card2: float64 -> float16, na_count=8933, n_uniq=501
# Column card3: float64 -> float16, na_count=1565, n_uniq=115
# Column card4: object -> object, na_count=1577, n_uniq=5
# Column card5: float64 -> float16, na_count=4259, n_uniq=120
# Column card6: object -> object, na_count=1571, n_uniq=5
# Column addr1: float64 -> float16, na_count=65706, n_uniq=333
# Column addr2: float64 -> float16, na_count=65706, n_uniq=75
# Column dist1: float64 -> float32, na_count=352271, n_uniq=2652
# Column dist2: float64 -> float32, na_count=552913, n_uniq=1752
# Column P_emaildomain: object -> object, na_count=94456, n_uniq=60
# Column R_emaildomain: object -> object, na_count=453249, n_uniq=61
# Column C1: float64 -> int16, na_count=0, n_uniq=1657
# Column C2: float64 -> int16, na_count=0, n_uniq=1216
# Column C3: float64 -> int8, na_count=0, n_uniq=27
# Column C4: float64 -> int16, na_count=0, n_uniq=1260
# Column C5: float64 -> int16, na_count=0, n_uniq=319
# Column C6: float64 -> int16, na_count=0, n_uniq=1328
# Column C7: float64 -> int16, na_count=0, n_uniq=1103
# Column C8: float64 -> int16, na_count=0, n_uniq=1253
# Column C9: float64 -> int16, na_count=0, n_uniq=205
# Column C10: float64 -> int16, na_count=0, n_uniq=1231
# Column C11: float64 -> int16, na_count=0, n_uniq=1476
# Column C12: float64 -> int16, na_count=0, n_uniq=1199
# Column C13: float64 -> int16, na_count=0, n_uniq=1597
# Column C14: float64 -> int16, na_count=0, n_uniq=1108
# Column D1: float64 -> float16, na_count=1269, n_uniq=642
# Column D2: float64 -> float16, na_count=280797, n_uniq=642
# Column D3: float64 -> float16, na_count=262878, n_uniq=650
# Column D4: float64 -> float16, na_count=168922, n_uniq=809
# Column D5: float64 -> float16, na_count=309841, n_uniq=689
# Column D6: float64 -> float16, na_count=517353, n_uniq=830
# Column D7: float64 -> float16, na_count=551623, n_uniq=598
# Column D8: float64 -> float32, na_count=515614, n_uniq=12354
# Column D9: float64 -> float16, na_count=515614, n_uniq=25
# Column D10: float64 -> float16, na_count=76022, n_uniq=819
# Column D11: float64 -> float16, na_count=279287, n_uniq=677
# Column D12: float64 -> float16, na_count=525823, n_uniq=636
# Column D13: float64 -> float16, na_count=528588, n_uniq=578
# Column D14: float64 -> float16, na_count=528353, n_uniq=803
# Column D15: float64 -> float16, na_count=89113, n_uniq=860
# Column M1: object -> object, na_count=271100, n_uniq=3
# Column M2: object -> object, na_count=271100, n_uniq=3
# Column M3: object -> object, na_count=271100, n_uniq=3
# Column M4: object -> object, na_count=281444, n_uniq=4
# Column M5: object -> object, na_count=350482, n_uniq=3
# Column M6: object -> object, na_count=169360, n_uniq=3
# Column M7: object -> object, na_count=346265, n_uniq=3
# Column M8: object -> object, na_count=346252, n_uniq=3
# Column M9: object -> object, na_count=346252, n_uniq=3
# Column V1: float64 -> float16, na_count=279287, n_uniq=3
# Column V2: float64 -> float16, na_count=279287, n_uniq=10
# Column V3: float64 -> float16, na_count=279287, n_uniq=11
# Column V4: float64 -> float16, na_count=279287, n_uniq=8
# Column V5: float64 -> float16, na_count=279287, n_uniq=8
# Column V6: float64 -> float16, na_count=279287, n_uniq=11
# Column V7: float64 -> float16, na_count=279287, n_uniq=11
# Column V8: float64 -> float16, na_count=279287, n_uniq=10
# Column V9: float64 -> float16, na_count=279287, n_uniq=10
# Column V10: float64 -> float16, na_count=279287, n_uniq=6
# Column V11: float64 -> float16, na_count=279287, n_uniq=7
# Column V12: float64 -> float16, na_count=76073, n_uniq=5
# Column V13: float64 -> float16, na_count=76073, n_uniq=8
# Column V14: float64 -> float16, na_count=76073, n_uniq=3
# Column V15: float64 -> float16, na_count=76073, n_uniq=9
# Column V16: float64 -> float16, na_count=76073, n_uniq=16
# Column V17: float64 -> float16, na_count=76073, n_uniq=17
# Column V18: float64 -> float16, na_count=76073, n_uniq=17
# Column V19: float64 -> float16, na_count=76073, n_uniq=9
# Column V20: float64 -> float16, na_count=76073, n_uniq=16
# Column V21: float64 -> float16, na_count=76073, n_uniq=7
# Column V22: float64 -> float16, na_count=76073, n_uniq=10
# Column V23: float64 -> float16, na_count=76073, n_uniq=15
# Column V24: float64 -> float16, na_count=76073, n_uniq=15
# Column V25: float64 -> float16, na_count=76073, n_uniq=8
# Column V26: float64 -> float16, na_count=76073, n_uniq=14
# Column V27: float64 -> float16, na_count=76073, n_uniq=5
# Column V28: float64 -> float16, na_count=76073, n_uniq=5
# Column V29: float64 -> float16, na_count=76073, n_uniq=7
# Column V30: float64 -> float16, na_count=76073, n_uniq=9
# Column V31: float64 -> float16, na_count=76073, n_uniq=9
# Column V32: float64 -> float16, na_count=76073, n_uniq=16
# Column V33: float64 -> float16, na_count=76073, n_uniq=8
# Column V34: float64 -> float16, na_count=76073, n_uniq=14
# Column V35: float64 -> float16, na_count=168969, n_uniq=5
# Column V36: float64 -> float16, na_count=168969, n_uniq=7
# Column V37: float64 -> float16, na_count=168969, n_uniq=56
# Column V38: float64 -> float16, na_count=168969, n_uniq=56
# Column V39: float64 -> float16, na_count=168969, n_uniq=17
# Column V40: float64 -> float16, na_count=168969, n_uniq=19
# Column V41: float64 -> float16, na_count=168969, n_uniq=3
# Column V42: float64 -> float16, na_count=168969, n_uniq=10
# Column V43: float64 -> float16, na_count=168969, n_uniq=10
# Column V44: float64 -> float16, na_count=168969, n_uniq=50
# Column V45: float64 -> float16, na_count=168969, n_uniq=50
# Column V46: float64 -> float16, na_count=168969, n_uniq=8
# Column V47: float64 -> float16, na_count=168969, n_uniq=10
# Column V48: float64 -> float16, na_count=168969, n_uniq=7
# Column V49: float64 -> float16, na_count=168969, n_uniq=7
# Column V50: float64 -> float16, na_count=168969, n_uniq=7
# Column V51: float64 -> float16, na_count=168969, n_uniq=8
# Column V52: float64 -> float16, na_count=168969, n_uniq=10
# Column V53: float64 -> float16, na_count=77096, n_uniq=7
# Column V54: float64 -> float16, na_count=77096, n_uniq=8
# Column V55: float64 -> float16, na_count=77096, n_uniq=19
# Column V56: float64 -> float16, na_count=77096, n_uniq=53
# Column V57: float64 -> float16, na_count=77096, n_uniq=8
# Column V58: float64 -> float16, na_count=77096, n_uniq=12
# Column V59: float64 -> float16, na_count=77096, n_uniq=18
# Column V60: float64 -> float16, na_count=77096, n_uniq=18
# Column V61: float64 -> float16, na_count=77096, n_uniq=8
# Column V62: float64 -> float16, na_count=77096, n_uniq=12
# Column V63: float64 -> float16, na_count=77096, n_uniq=9
# Column V64: float64 -> float16, na_count=77096, n_uniq=9
# Column V65: float64 -> float16, na_count=77096, n_uniq=3
# Column V66: float64 -> float16, na_count=77096, n_uniq=9
# Column V67: float64 -> float16, na_count=77096, n_uniq=10
# Column V68: float64 -> float16, na_count=77096, n_uniq=4
# Column V69: float64 -> float16, na_count=77096, n_uniq=7
# Column V70: float64 -> float16, na_count=77096, n_uniq=8
# Column V71: float64 -> float16, na_count=77096, n_uniq=8
# Column V72: float64 -> float16, na_count=77096, n_uniq=12
# Column V73: float64 -> float16, na_count=77096, n_uniq=9
# Column V74: float64 -> float16, na_count=77096, n_uniq=10
# Column V75: float64 -> float16, na_count=89164, n_uniq=6
# Column V76: float64 -> float16, na_count=89164, n_uniq=8
# Column V77: float64 -> float16, na_count=89164, n_uniq=32
# Column V78: float64 -> float16, na_count=89164, n_uniq=33
# Column V79: float64 -> float16, na_count=89164, n_uniq=9
# Column V80: float64 -> float16, na_count=89164, n_uniq=21
# Column V81: float64 -> float16, na_count=89164, n_uniq=21
# Column V82: float64 -> float16, na_count=89164, n_uniq=9
# Column V83: float64 -> float16, na_count=89164, n_uniq=9
# Column V84: float64 -> float16, na_count=89164, n_uniq=9
# Column V85: float64 -> float16, na_count=89164, n_uniq=9
# Column V86: float64 -> float16, na_count=89164, n_uniq=32
# Column V87: float64 -> float16, na_count=89164, n_uniq=32
# Column V88: float64 -> float16, na_count=89164, n_uniq=3
# Column V89: float64 -> float16, na_count=89164, n_uniq=4
# Column V90: float64 -> float16, na_count=89164, n_uniq=7
# Column V91: float64 -> float16, na_count=89164, n_uniq=8
# Column V92: float64 -> float16, na_count=89164, n_uniq=9
# Column V93: float64 -> float16, na_count=89164, n_uniq=9
# Column V94: float64 -> float16, na_count=89164, n_uniq=4
# Column V95: float64 -> float16, na_count=314, n_uniq=882
# Column V96: float64 -> float16, na_count=314, n_uniq=1411
# Column V97: float64 -> float16, na_count=314, n_uniq=977
# Column V98: float64 -> float16, na_count=314, n_uniq=14
# Column V99: float64 -> float16, na_count=314, n_uniq=90
# Column V100: float64 -> float16, na_count=314, n_uniq=30
# Column V101: float64 -> float16, na_count=314, n_uniq=871
# Column V102: float64 -> float16, na_count=314, n_uniq=1286
# Column V103: float64 -> float16, na_count=314, n_uniq=929
# Column V104: float64 -> float16, na_count=314, n_uniq=17
# Column V105: float64 -> float16, na_count=314, n_uniq=101
# Column V106: float64 -> float16, na_count=314, n_uniq=57
# Column V107: float64 -> float16, na_count=314, n_uniq=3
# Column V108: float64 -> float16, na_count=314, n_uniq=9
# Column V109: float64 -> float16, na_count=314, n_uniq=9
# Column V110: float64 -> float16, na_count=314, n_uniq=9
# Column V111: float64 -> float16, na_count=314, n_uniq=11
# Column V112: float64 -> float16, na_count=314, n_uniq=11
# Column V113: float64 -> float16, na_count=314, n_uniq=11
# Column V114: float64 -> float16, na_count=314, n_uniq=8
# Column V115: float64 -> float16, na_count=314, n_uniq=8
# Column V116: float64 -> float16, na_count=314, n_uniq=8
# Column V117: float64 -> float16, na_count=314, n_uniq=5
# Column V118: float64 -> float16, na_count=314, n_uniq=5
# Column V119: float64 -> float16, na_count=314, n_uniq=5
# Column V120: float64 -> float16, na_count=314, n_uniq=5
# Column V121: float64 -> float16, na_count=314, n_uniq=5
# Column V122: float64 -> float16, na_count=314, n_uniq=5
# Column V123: float64 -> float16, na_count=314, n_uniq=15
# Column V124: float64 -> float16, na_count=314, n_uniq=15
# Column V125: float64 -> float16, na_count=314, n_uniq=15
# Column V126: float64 -> float32, na_count=314, n_uniq=10300
# Column V127: float64 -> float32, na_count=314, n_uniq=24415
# Column V128: float64 -> float32, na_count=314, n_uniq=14508
# Column V129: float64 -> float32, na_count=314, n_uniq=1969
# Column V130: float64 -> float32, na_count=314, n_uniq=12333
# Column V131: float64 -> float32, na_count=314, n_uniq=4445
# Column V132: float64 -> float32, na_count=314, n_uniq=6561
# Column V133: float64 -> float32, na_count=314, n_uniq=9950
# Column V134: float64 -> float32, na_count=314, n_uniq=8179
# Column V135: float64 -> float32, na_count=314, n_uniq=3725
# Column V136: float64 -> float32, na_count=314, n_uniq=4853
# Column V137: float64 -> float32, na_count=314, n_uniq=4253
# Column V138: float64 -> float16, na_count=508595, n_uniq=24
# Column V139: float64 -> float16, na_count=508595, n_uniq=35
# Column V140: float64 -> float16, na_count=508595, n_uniq=35
# Column V141: float64 -> float16, na_count=508595, n_uniq=7
# Column V142: float64 -> float16, na_count=508595, n_uniq=11
# Column V143: float64 -> float16, na_count=508589, n_uniq=871
# Column V144: float64 -> float16, na_count=508589, n_uniq=64
# Column V145: float64 -> float16, na_count=508589, n_uniq=261
# Column V146: float64 -> float16, na_count=508595, n_uniq=26
# Column V147: float64 -> float16, na_count=508595, n_uniq=28
# Column V148: float64 -> float16, na_count=508595, n_uniq=22
# Column V149: float64 -> float16, na_count=508595, n_uniq=22
# Column V150: float64 -> float32, na_count=508589, n_uniq=1997
# Column V151: float64 -> float16, na_count=508589, n_uniq=57
# Column V152: float64 -> float16, na_count=508589, n_uniq=40
# Column V153: float64 -> float16, na_count=508595, n_uniq=20
# Column V154: float64 -> float16, na_count=508595, n_uniq=20
# Column V155: float64 -> float16, na_count=508595, n_uniq=26
# Column V156: float64 -> float16, na_count=508595, n_uniq=26
# Column V157: float64 -> float16, na_count=508595, n_uniq=26
# Column V158: float64 -> float16, na_count=508595, n_uniq=26
# Column V159: float64 -> float32, na_count=508589, n_uniq=6664
# Column V160: float64 -> float32, na_count=508589, n_uniq=9622
# Column V161: float64 -> float16, na_count=508595, n_uniq=80
# Column V162: float64 -> float16, na_count=508595, n_uniq=186
# Column V163: float64 -> float16, na_count=508595, n_uniq=107
# Column V164: float64 -> float32, na_count=508589, n_uniq=1979
# Column V165: float64 -> float32, na_count=508589, n_uniq=2548
# Column V166: float64 -> float32, na_count=508589, n_uniq=988
# Column V167: float64 -> float16, na_count=450909, n_uniq=874
# Column V168: float64 -> float16, na_count=450909, n_uniq=966
# Column V169: float64 -> float16, na_count=450721, n_uniq=21
# Column V170: float64 -> float16, na_count=450721, n_uniq=50
# Column V171: float64 -> float16, na_count=450721, n_uniq=63
# Column V172: float64 -> float16, na_count=450909, n_uniq=33
# Column V173: float64 -> float16, na_count=450909, n_uniq=9
# Column V174: float64 -> float16, na_count=450721, n_uniq=10
# Column V175: float64 -> float16, na_count=450721, n_uniq=16
# Column V176: float64 -> float16, na_count=450909, n_uniq=50
# Column V177: float64 -> float16, na_count=450909, n_uniq=863
# Column V178: float64 -> float16, na_count=450909, n_uniq=1237
# Column V179: float64 -> float16, na_count=450909, n_uniq=922
# Column V180: float64 -> float16, na_count=450721, n_uniq=85
# Column V181: float64 -> float16, na_count=450909, n_uniq=26
# Column V182: float64 -> float16, na_count=450909, n_uniq=85
# Column V183: float64 -> float16, na_count=450909, n_uniq=43
# Column V184: float64 -> float16, na_count=450721, n_uniq=18
# Column V185: float64 -> float16, na_count=450721, n_uniq=33
# Column V186: float64 -> float16, na_count=450909, n_uniq=40
# Column V187: float64 -> float16, na_count=450909, n_uniq=216
# Column V188: float64 -> float16, na_count=450721, n_uniq=32
# Column V189: float64 -> float16, na_count=450721, n_uniq=32
# Column V190: float64 -> float16, na_count=450909, n_uniq=44
# Column V191: float64 -> float16, na_count=450909, n_uniq=23
# Column V192: float64 -> float16, na_count=450909, n_uniq=46
# Column V193: float64 -> float16, na_count=450909, n_uniq=39
# Column V194: float64 -> float16, na_count=450721, n_uniq=9
# Column V195: float64 -> float16, na_count=450721, n_uniq=18
# Column V196: float64 -> float16, na_count=450909, n_uniq=40
# Column V197: float64 -> float16, na_count=450721, n_uniq=16
# Column V198: float64 -> float16, na_count=450721, n_uniq=23
# Column V199: float64 -> float16, na_count=450909, n_uniq=47
# Column V200: float64 -> float16, na_count=450721, n_uniq=47
# Column V201: float64 -> float16, na_count=450721, n_uniq=57
# Column V202: float64 -> float32, na_count=450909, n_uniq=10971
# Column V203: float64 -> float32, na_count=450909, n_uniq=14952
# Column V204: float64 -> float32, na_count=450909, n_uniq=12859
# Column V205: float64 -> float32, na_count=450909, n_uniq=2241
# Column V206: float64 -> float32, na_count=450909, n_uniq=1781
# Column V207: float64 -> float32, na_count=450909, n_uniq=3247
# Column V208: float64 -> float32, na_count=450721, n_uniq=2553
# Column V209: float64 -> float32, na_count=450721, n_uniq=3452
# Column V210: float64 -> float32, na_count=450721, n_uniq=2837
# Column V211: float64 -> float32, na_count=450909, n_uniq=7625
# Column V212: float64 -> float32, na_count=450909, n_uniq=8869
# Column V213: float64 -> float32, na_count=450909, n_uniq=8318
# Column V214: float64 -> float32, na_count=450909, n_uniq=2283
# Column V215: float64 -> float32, na_count=450909, n_uniq=2748
# Column V216: float64 -> float32, na_count=450909, n_uniq=2533
# Column V217: float64 -> float16, na_count=460110, n_uniq=305
# Column V218: float64 -> float16, na_count=460110, n_uniq=402
# Column V219: float64 -> float16, na_count=460110, n_uniq=380
# Column V220: float64 -> float16, na_count=449124, n_uniq=27
# Column V221: float64 -> float16, na_count=449124, n_uniq=78
# Column V222: float64 -> float16, na_count=449124, n_uniq=77
# Column V223: float64 -> float16, na_count=460110, n_uniq=18
# Column V224: float64 -> float16, na_count=460110, n_uniq=80
# Column V225: float64 -> float16, na_count=460110, n_uniq=36
# Column V226: float64 -> float16, na_count=460110, n_uniq=82
# Column V227: float64 -> float16, na_count=449124, n_uniq=51
# Column V228: float64 -> float16, na_count=460110, n_uniq=56
# Column V229: float64 -> float16, na_count=460110, n_uniq=92
# Column V230: float64 -> float16, na_count=460110, n_uniq=67
# Column V231: float64 -> float16, na_count=460110, n_uniq=295
# Column V232: float64 -> float16, na_count=460110, n_uniq=339
# Column V233: float64 -> float16, na_count=460110, n_uniq=334
# Column V234: float64 -> float16, na_count=449124, n_uniq=123
# Column V235: float64 -> float16, na_count=460110, n_uniq=25
# Column V236: float64 -> float16, na_count=460110, n_uniq=47
# Column V237: float64 -> float16, na_count=460110, n_uniq=41
# Column V238: float64 -> float16, na_count=449124, n_uniq=25
# Column V239: float64 -> float16, na_count=449124, n_uniq=25
# Column V240: float64 -> float16, na_count=460110, n_uniq=7
# Column V241: float64 -> float16, na_count=460110, n_uniq=6
# Column V242: float64 -> float16, na_count=460110, n_uniq=22
# Column V243: float64 -> float16, na_count=460110, n_uniq=44
# Column V244: float64 -> float16, na_count=460110, n_uniq=24
# Column V245: float64 -> float16, na_count=449124, n_uniq=59
# Column V246: float64 -> float16, na_count=460110, n_uniq=47
# Column V247: float64 -> float16, na_count=460110, n_uniq=20
# Column V248: float64 -> float16, na_count=460110, n_uniq=24
# Column V249: float64 -> float16, na_count=460110, n_uniq=24
# Column V250: float64 -> float16, na_count=449124, n_uniq=20
# Column V251: float64 -> float16, na_count=449124, n_uniq=20
# Column V252: float64 -> float16, na_count=460110, n_uniq=26
# Column V253: float64 -> float16, na_count=460110, n_uniq=67
# Column V254: float64 -> float16, na_count=460110, n_uniq=46
# Column V255: float64 -> float16, na_count=449124, n_uniq=47
# Column V256: float64 -> float16, na_count=449124, n_uniq=49
# Column V257: float64 -> float16, na_count=460110, n_uniq=50
# Column V258: float64 -> float16, na_count=460110, n_uniq=68
# Column V259: float64 -> float16, na_count=449124, n_uniq=69
# Column V260: float64 -> float16, na_count=460110, n_uniq=10
# Column V261: float64 -> float16, na_count=460110, n_uniq=42
# Column V262: float64 -> float16, na_count=460110, n_uniq=22
# Column V263: float64 -> float32, na_count=460110, n_uniq=10423
# Column V264: float64 -> float32, na_count=460110, n_uniq=13359
# Column V265: float64 -> float32, na_count=460110, n_uniq=11758
# Column V266: float64 -> float32, na_count=460110, n_uniq=2179
# Column V267: float64 -> float32, na_count=460110, n_uniq=3617
# Column V268: float64 -> float32, na_count=460110, n_uniq=2757
# Column V269: float64 -> float32, na_count=460110, n_uniq=152
# Column V270: float64 -> float32, na_count=449124, n_uniq=2341
# Column V271: float64 -> float32, na_count=449124, n_uniq=2788
# Column V272: float64 -> float32, na_count=449124, n_uniq=2508
# Column V273: float64 -> float32, na_count=460110, n_uniq=7178
# Column V274: float64 -> float32, na_count=460110, n_uniq=8316
# Column V275: float64 -> float32, na_count=460110, n_uniq=7777
# Column V276: float64 -> float32, na_count=460110, n_uniq=2264
# Column V277: float64 -> float32, na_count=460110, n_uniq=2541
# Column V278: float64 -> float32, na_count=460110, n_uniq=2399
# Column V279: float64 -> float16, na_count=12, n_uniq=882
# Column V280: float64 -> float16, na_count=12, n_uniq=976
# Column V281: float64 -> float16, na_count=1269, n_uniq=24
# Column V282: float64 -> float16, na_count=1269, n_uniq=34
# Column V283: float64 -> float16, na_count=1269, n_uniq=63
# Column V284: float64 -> float16, na_count=12, n_uniq=14
# Column V285: float64 -> float16, na_count=12, n_uniq=97
# Column V286: float64 -> float16, na_count=12, n_uniq=10
# Column V287: float64 -> float16, na_count=12, n_uniq=33
# Column V288: float64 -> float16, na_count=1269, n_uniq=12
# Column V289: float64 -> float16, na_count=1269, n_uniq=14
# Column V290: float64 -> float16, na_count=12, n_uniq=59
# Column V291: float64 -> float16, na_count=12, n_uniq=220
# Column V292: float64 -> float16, na_count=12, n_uniq=174
# Column V293: float64 -> float16, na_count=12, n_uniq=871
# Column V294: float64 -> float16, na_count=12, n_uniq=1287
# Column V295: float64 -> float16, na_count=12, n_uniq=929
# Column V296: float64 -> float16, na_count=1269, n_uniq=95
# Column V297: float64 -> float16, na_count=12, n_uniq=14
# Column V298: float64 -> float16, na_count=12, n_uniq=95
# Column V299: float64 -> float16, na_count=12, n_uniq=51
# Column V300: float64 -> float16, na_count=1269, n_uniq=13
# Column V301: float64 -> float16, na_count=1269, n_uniq=15
# Column V302: float64 -> float16, na_count=12, n_uniq=18
# Column V303: float64 -> float16, na_count=12, n_uniq=22
# Column V304: float64 -> float16, na_count=12, n_uniq=18
# Column V305: float64 -> float16, na_count=12, n_uniq=3
# Column V306: float64 -> float32, na_count=12, n_uniq=16211
# Column V307: float64 -> float32, na_count=12, n_uniq=37368
# Column V308: float64 -> float32, na_count=12, n_uniq=23065
# Column V309: float64 -> float32, na_count=12, n_uniq=4237
# Column V310: float64 -> float32, na_count=12, n_uniq=19137
# Column V311: float64 -> float32, na_count=12, n_uniq=3099
# Column V312: float64 -> float32, na_count=12, n_uniq=8069
# Column V313: float64 -> float32, na_count=1269, n_uniq=5530
# Column V314: float64 -> float32, na_count=1269, n_uniq=11378
# Column V315: float64 -> float32, na_count=1269, n_uniq=6974
# Column V316: float64 -> float32, na_count=12, n_uniq=9815
# Column V317: float64 -> float32, na_count=12, n_uniq=15185
# Column V318: float64 -> float32, na_count=12, n_uniq=12310
# Column V319: float64 -> float32, na_count=12, n_uniq=4800
# Column V320: float64 -> float32, na_count=12, n_uniq=6440
# Column V321: float64 -> float32, na_count=12, n_uniq=5561
# Column V322: float64 -> float16, na_count=508189, n_uniq=882
# Column V323: float64 -> float16, na_count=508189, n_uniq=1412
# Column V324: float64 -> float16, na_count=508189, n_uniq=977
# Column V325: float64 -> float16, na_count=508189, n_uniq=14
# Column V326: float64 -> float16, na_count=508189, n_uniq=46
# Column V327: float64 -> float16, na_count=508189, n_uniq=20
# Column V328: float64 -> float16, na_count=508189, n_uniq=17
# Column V329: float64 -> float16, na_count=508189, n_uniq=101
# Column V330: float64 -> float16, na_count=508189, n_uniq=57
# Column V331: float64 -> float32, na_count=508189, n_uniq=1759
# Column V332: float64 -> float32, na_count=508189, n_uniq=2454
# Column V333: float64 -> float32, na_count=508189, n_uniq=1972
# Column V334: float64 -> float32, na_count=508189, n_uniq=144
# Column V335: float64 -> float32, na_count=508189, n_uniq=673
# Column V336: float64 -> float32, na_count=508189, n_uniq=357
# Column V337: float64 -> float32, na_count=508189, n_uniq=255
# Column V338: float64 -> float32, na_count=508189, n_uniq=381
# Column V339: float64 -> float32, na_count=508189, n_uniq=335
# Column DT: float64 -> int16, na_count=0, n_uniq=182
# Column D1achr: float64 -> float16, na_count=1269, n_uniq=792
# Column D2achr: float64 -> float16, na_count=280797, n_uniq=786
# Column D4achr: float64 -> float16, na_count=168922, n_uniq=837
# Column D6achr: float64 -> float16, na_count=517353, n_uniq=820
# Column D10achr: float64 -> float16, na_count=76022, n_uniq=831
# Column D11achr: float64 -> float16, na_count=279287, n_uniq=676
# Column D12achr: float64 -> float16, na_count=525823, n_uniq=664
# Column D13achr: float64 -> float16, na_count=528588, n_uniq=604
# Column D14achr: float64 -> float16, na_count=528353, n_uniq=821
# Column D15achr: float64 -> float16, na_count=89113, n_uniq=851
# Mem. usage decreased from 2172.71 Mb to 940.47 Mb (56.7% reduction)
# Column TransactionID: int64 -> int32, na_count=0, n_uniq=506691
# Column TransactionDT: int64 -> int32, na_count=0, n_uniq=494686
# Column TransactionAmt: float64 -> float32, na_count=0, n_uniq=14119
# Column ProductCD: object -> object, na_count=0, n_uniq=5
# Column card1: int64 -> int16, na_count=0, n_uniq=13244
# Column card2: float64 -> float16, na_count=8654, n_uniq=498
# Column card3: float64 -> float16, na_count=3002, n_uniq=116
# Column card4: object -> object, na_count=3086, n_uniq=5
# Column card5: float64 -> float16, na_count=4547, n_uniq=103
# Column card6: object -> object, na_count=3007, n_uniq=4
# Column addr1: float64 -> float16, na_count=65609, n_uniq=293
# Column addr2: float64 -> float16, na_count=65609, n_uniq=73
# Column dist1: float64 -> float32, na_count=291217, n_uniq=1989
# Column dist2: float64 -> float32, na_count=470255, n_uniq=1815
# Column P_emaildomain: object -> object, na_count=69192, n_uniq=61
# Column R_emaildomain: object -> object, na_count=370821, n_uniq=61
# Column C1: float64 -> float32, na_count=3, n_uniq=1175
# Column C2: float64 -> float32, na_count=3, n_uniq=1124
# Column C3: float64 -> float16, na_count=3, n_uniq=32
# Column C4: float64 -> float16, na_count=3, n_uniq=729
# Column C5: float64 -> float16, na_count=3, n_uniq=354
# Column C6: float64 -> float16, na_count=3, n_uniq=835
# Column C7: float64 -> float16, na_count=3, n_uniq=519
# Column C8: float64 -> float16, na_count=3, n_uniq=443
# Column C9: float64 -> float16, na_count=3, n_uniq=355
# Column C10: float64 -> float16, na_count=3, n_uniq=457
# Column C11: float64 -> float32, na_count=3, n_uniq=938
# Column C12: float64 -> float32, na_count=3, n_uniq=664
# Column C13: float64 -> float16, na_count=4748, n_uniq=1070
# Column C14: float64 -> float16, na_count=3, n_uniq=570
# Column D1: float64 -> float16, na_count=6031, n_uniq=643
# Column D2: float64 -> float16, na_count=234769, n_uniq=643
# Column D3: float64 -> float16, na_count=203142, n_uniq=888
# Column D4: float64 -> float16, na_count=76851, n_uniq=1057
# Column D5: float64 -> float16, na_count=224375, n_uniq=962
# Column D6: float64 -> float16, na_count=381908, n_uniq=1073
# Column D7: float64 -> float16, na_count=446558, n_uniq=905
# Column D8: float64 -> float32, na_count=432353, n_uniq=13245
# Column D9: float64 -> float16, na_count=432353, n_uniq=25
# Column D10: float64 -> float16, na_count=12545, n_uniq=1076
# Column D11: float64 -> float16, na_count=176518, n_uniq=881
# Column D12: float64 -> float16, na_count=437437, n_uniq=867
# Column D13: float64 -> float16, na_count=383307, n_uniq=806
# Column D14: float64 -> float16, na_count=391497, n_uniq=1032
# Column D15: float64 -> float16, na_count=12069, n_uniq=1079
# Column M1: object -> object, na_count=176639, n_uniq=3
# Column M2: object -> object, na_count=176639, n_uniq=3
# Column M3: object -> object, na_count=176639, n_uniq=3
# Column M4: object -> object, na_count=237745, n_uniq=4
# Column M5: object -> object, na_count=309632, n_uniq=3
# Column M6: object -> object, na_count=158939, n_uniq=3
# Column M7: object -> object, na_count=235018, n_uniq=3
# Column M8: object -> object, na_count=235004, n_uniq=3
# Column M9: object -> object, na_count=235004, n_uniq=3
# Column V1: float64 -> float16, na_count=176518, n_uniq=3
# Column V2: float64 -> float16, na_count=176518, n_uniq=13
# Column V3: float64 -> float16, na_count=176518, n_uniq=13
# Column V4: float64 -> float16, na_count=176518, n_uniq=11
# Column V5: float64 -> float16, na_count=176518, n_uniq=12
# Column V6: float64 -> float16, na_count=176518, n_uniq=14
# Column V7: float64 -> float16, na_count=176518, n_uniq=14
# Column V8: float64 -> float16, na_count=176518, n_uniq=13
# Column V9: float64 -> float16, na_count=176518, n_uniq=13
# Column V10: float64 -> float16, na_count=176518, n_uniq=7
# Column V11: float64 -> float16, na_count=176518, n_uniq=9
# Column V12: float64 -> float16, na_count=12589, n_uniq=6
# Column V13: float64 -> float16, na_count=12589, n_uniq=8
# Column V14: float64 -> float16, na_count=12589, n_uniq=3
# Column V15: float64 -> float16, na_count=12589, n_uniq=14
# Column V16: float64 -> float16, na_count=12589, n_uniq=24
# Column V17: float64 -> float16, na_count=12589, n_uniq=12
# Column V18: float64 -> float16, na_count=12589, n_uniq=12
# Column V19: float64 -> float16, na_count=12589, n_uniq=14
# Column V20: float64 -> float16, na_count=12589, n_uniq=24
# Column V21: float64 -> float16, na_count=12589, n_uniq=7
# Column V22: float64 -> float16, na_count=12589, n_uniq=9
# Column V23: float64 -> float16, na_count=12589, n_uniq=17
# Column V24: float64 -> float16, na_count=12589, n_uniq=27
# Column V25: float64 -> float16, na_count=12589, n_uniq=14
# Column V26: float64 -> float16, na_count=12589, n_uniq=24
# Column V27: float64 -> float16, na_count=12589, n_uniq=9
# Column V28: float64 -> float16, na_count=12589, n_uniq=9
# Column V29: float64 -> float16, na_count=12589, n_uniq=6
# Column V30: float64 -> float16, na_count=12589, n_uniq=9
# Column V31: float64 -> float16, na_count=12589, n_uniq=14
# Column V32: float64 -> float16, na_count=12589, n_uniq=24
# Column V33: float64 -> float16, na_count=12589, n_uniq=14
# Column V34: float64 -> float16, na_count=12589, n_uniq=24
# Column V35: float64 -> float16, na_count=76854, n_uniq=6
# Column V36: float64 -> float16, na_count=76854, n_uniq=8
# Column V37: float64 -> float16, na_count=76854, n_uniq=51
# Column V38: float64 -> float16, na_count=76854, n_uniq=54
# Column V39: float64 -> float16, na_count=76854, n_uniq=23
# Column V40: float64 -> float16, na_count=76854, n_uniq=24
# Column V41: float64 -> float16, na_count=76854, n_uniq=3
# Column V42: float64 -> float16, na_count=76854, n_uniq=10
# Column V43: float64 -> float16, na_count=76854, n_uniq=13
# Column V44: float64 -> float16, na_count=76854, n_uniq=49
# Column V45: float64 -> float16, na_count=76854, n_uniq=71
# Column V46: float64 -> float16, na_count=76854, n_uniq=10
# Column V47: float64 -> float16, na_count=76854, n_uniq=13
# Column V48: float64 -> float16, na_count=76854, n_uniq=6
# Column V49: float64 -> float16, na_count=76854, n_uniq=9
# Column V50: float64 -> float16, na_count=76854, n_uniq=9
# Column V51: float64 -> float16, na_count=76854, n_uniq=10
# Column V52: float64 -> float16, na_count=76854, n_uniq=12
# Column V53: float64 -> float16, na_count=12899, n_uniq=7
# Column V54: float64 -> float16, na_count=12899, n_uniq=9
# Column V55: float64 -> float16, na_count=12899, n_uniq=51
# Column V56: float64 -> float16, na_count=12899, n_uniq=52
# Column V57: float64 -> float16, na_count=12899, n_uniq=8
# Column V58: float64 -> float16, na_count=12899, n_uniq=10
# Column V59: float64 -> float16, na_count=12899, n_uniq=14
# Column V60: float64 -> float16, na_count=12899, n_uniq=19
# Column V61: float64 -> float16, na_count=12899, n_uniq=8
# Column V62: float64 -> float16, na_count=12899, n_uniq=10
# Column V63: float64 -> float16, na_count=12899, n_uniq=10
# Column V64: float64 -> float16, na_count=12899, n_uniq=12
# Column V65: float64 -> float16, na_count=12899, n_uniq=3
# Column V66: float64 -> float16, na_count=12899, n_uniq=10
# Column V67: float64 -> float16, na_count=12899, n_uniq=12
# Column V68: float64 -> float16, na_count=12899, n_uniq=9
# Column V69: float64 -> float16, na_count=12899, n_uniq=6
# Column V70: float64 -> float16, na_count=12899, n_uniq=10
# Column V71: float64 -> float16, na_count=12899, n_uniq=8
# Column V72: float64 -> float16, na_count=12899, n_uniq=10
# Column V73: float64 -> float16, na_count=12899, n_uniq=10
# Column V74: float64 -> float16, na_count=12899, n_uniq=12
# Column V75: float64 -> float16, na_count=12081, n_uniq=7
# Column V76: float64 -> float16, na_count=12081, n_uniq=9
# Column V77: float64 -> float16, na_count=12081, n_uniq=82
# Column V78: float64 -> float16, na_count=12081, n_uniq=82
# Column V79: float64 -> float16, na_count=12081, n_uniq=9
# Column V80: float64 -> float16, na_count=12081, n_uniq=20
# Column V81: float64 -> float16, na_count=12081, n_uniq=20
# Column V82: float64 -> float16, na_count=12081, n_uniq=7
# Column V83: float64 -> float16, na_count=12081, n_uniq=9
# Column V84: float64 -> float16, na_count=12081, n_uniq=12
# Column V85: float64 -> float16, na_count=12081, n_uniq=12
# Column V86: float64 -> float16, na_count=12081, n_uniq=82
# Column V87: float64 -> float16, na_count=12081, n_uniq=82
# Column V88: float64 -> float16, na_count=12081, n_uniq=3
# Column V89: float64 -> float16, na_count=12081, n_uniq=9
# Column V90: float64 -> float16, na_count=12081, n_uniq=6
# Column V91: float64 -> float16, na_count=12081, n_uniq=10
# Column V92: float64 -> float16, na_count=12081, n_uniq=8
# Column V93: float64 -> float16, na_count=12081, n_uniq=9
# Column V94: float64 -> float16, na_count=12081, n_uniq=4
# Column V95: float64 -> int8, na_count=0, n_uniq=61
# Column V96: float64 -> int8, na_count=0, n_uniq=104
# Column V97: float64 -> int8, na_count=0, n_uniq=83
# Column V98: float64 -> int8, na_count=0, n_uniq=9
# Column V99: float64 -> int8, na_count=0, n_uniq=63
# Column V100: float64 -> int8, na_count=0, n_uniq=31
# Column V101: float64 -> int8, na_count=0, n_uniq=19
# Column V102: float64 -> int8, na_count=0, n_uniq=69
# Column V103: float64 -> int8, na_count=0, n_uniq=30
# Column V104: float64 -> int8, na_count=0, n_uniq=60
# Column V105: float64 -> int8, na_count=0, n_uniq=100
# Column V106: float64 -> int8, na_count=0, n_uniq=81
# Column V107: float64 -> int8, na_count=0, n_uniq=1
# Column V108: float64 -> int8, na_count=0, n_uniq=9
# Column V109: float64 -> int8, na_count=0, n_uniq=9
# Column V110: float64 -> int8, na_count=0, n_uniq=9
# Column V111: float64 -> int8, na_count=0, n_uniq=9
# Column V112: float64 -> int8, na_count=0, n_uniq=9
# Column V113: float64 -> int8, na_count=0, n_uniq=9
# Column V114: float64 -> int8, na_count=0, n_uniq=10
# Column V115: float64 -> int8, na_count=0, n_uniq=10
# Column V116: float64 -> int8, na_count=0, n_uniq=10
# Column V117: float64 -> int8, na_count=0, n_uniq=3
# Column V118: float64 -> int8, na_count=0, n_uniq=4
# Column V119: float64 -> int8, na_count=0, n_uniq=3
# Column V120: float64 -> int8, na_count=0, n_uniq=5
# Column V121: float64 -> int8, na_count=0, n_uniq=5
# Column V122: float64 -> int8, na_count=0, n_uniq=5
# Column V123: float64 -> int8, na_count=0, n_uniq=13
# Column V124: float64 -> int8, na_count=0, n_uniq=14
# Column V125: float64 -> int8, na_count=0, n_uniq=13
# Column V126: float64 -> float32, na_count=0, n_uniq=7845
# Column V127: float64 -> float32, na_count=0, n_uniq=18871
# Column V128: float64 -> float32, na_count=0, n_uniq=10913
# Column V129: float64 -> float32, na_count=0, n_uniq=1445
# Column V130: float64 -> float32, na_count=0, n_uniq=10195
# Column V131: float64 -> float32, na_count=0, n_uniq=3492
# Column V132: float64 -> float32, na_count=0, n_uniq=4444
# Column V133: float64 -> float32, na_count=0, n_uniq=6586
# Column V134: float64 -> float32, na_count=0, n_uniq=5445
# Column V135: float64 -> float32, na_count=0, n_uniq=3871
# Column V136: float64 -> float32, na_count=0, n_uniq=5158
# Column V137: float64 -> float32, na_count=0, n_uniq=4429
# Column V138: float64 -> float16, na_count=430906, n_uniq=22
# Column V139: float64 -> float16, na_count=430906, n_uniq=30
# Column V140: float64 -> float16, na_count=430906, n_uniq=61
# Column V141: float64 -> float16, na_count=430906, n_uniq=8
# Column V142: float64 -> float16, na_count=430906, n_uniq=13
# Column V143: float64 -> float16, na_count=430636, n_uniq=58
# Column V144: float64 -> float16, na_count=430636, n_uniq=87
# Column V145: float64 -> float16, na_count=430636, n_uniq=281
# Column V146: float64 -> float16, na_count=430906, n_uniq=14
# Column V147: float64 -> float16, na_count=430906, n_uniq=24
# Column V148: float64 -> float16, na_count=430906, n_uniq=13
# Column V149: float64 -> float16, na_count=430906, n_uniq=13
# Column V150: float64 -> float32, na_count=430636, n_uniq=2152
# Column V151: float64 -> float16, na_count=430636, n_uniq=59
# Column V152: float64 -> float16, na_count=430636, n_uniq=35
# Column V153: float64 -> float16, na_count=430906, n_uniq=10
# Column V154: float64 -> float16, na_count=430906, n_uniq=11
# Column V155: float64 -> float16, na_count=430906, n_uniq=13
# Column V156: float64 -> float16, na_count=430906, n_uniq=13
# Column V157: float64 -> float16, na_count=430906, n_uniq=15
# Column V158: float64 -> float16, na_count=430906, n_uniq=15
# Column V159: float64 -> float32, na_count=430636, n_uniq=6248
# Column V160: float64 -> float32, na_count=430636, n_uniq=7956
# Column V161: float64 -> float32, na_count=430906, n_uniq=77
# Column V162: float64 -> float32, na_count=430906, n_uniq=205
# Column V163: float64 -> float32, na_count=430906, n_uniq=111
# Column V164: float64 -> float32, na_count=430636, n_uniq=1027
# Column V165: float64 -> float32, na_count=430636, n_uniq=1502
# Column V166: float64 -> float32, na_count=430636, n_uniq=1521
# Column V167: float64 -> float16, na_count=369957, n_uniq=240
# Column V168: float64 -> float16, na_count=369957, n_uniq=259
# Column V169: float64 -> float16, na_count=370316, n_uniq=41
# Column V170: float64 -> float16, na_count=370316, n_uniq=65
# Column V171: float64 -> float16, na_count=370316, n_uniq=70
# Column V172: float64 -> float16, na_count=369957, n_uniq=39
# Column V173: float64 -> float16, na_count=369957, n_uniq=11
# Column V174: float64 -> float16, na_count=370316, n_uniq=8
# Column V175: float64 -> float16, na_count=370316, n_uniq=24
# Column V176: float64 -> float16, na_count=369957, n_uniq=240
# Column V177: float64 -> float16, na_count=369957, n_uniq=240
# Column V178: float64 -> float16, na_count=369957, n_uniq=259
# Column V179: float64 -> float16, na_count=369957, n_uniq=259
# Column V180: float64 -> float16, na_count=370316, n_uniq=181
# Column V181: float64 -> float16, na_count=369957, n_uniq=87
# Column V182: float64 -> float16, na_count=369957, n_uniq=127
# Column V183: float64 -> float16, na_count=369957, n_uniq=108
# Column V184: float64 -> float16, na_count=370316, n_uniq=14
# Column V185: float64 -> float16, na_count=370316, n_uniq=14
# Column V186: float64 -> float16, na_count=369957, n_uniq=41
# Column V187: float64 -> float16, na_count=369957, n_uniq=157
# Column V188: float64 -> float16, na_count=370316, n_uniq=46
# Column V189: float64 -> float16, na_count=370316, n_uniq=46
# Column V190: float64 -> float16, na_count=369957, n_uniq=226
# Column V191: float64 -> float16, na_count=369957, n_uniq=22
# Column V192: float64 -> float16, na_count=369957, n_uniq=39
# Column V193: float64 -> float16, na_count=369957, n_uniq=34
# Column V194: float64 -> float16, na_count=370316, n_uniq=9
# Column V195: float64 -> float16, na_count=370316, n_uniq=20
# Column V196: float64 -> float16, na_count=369957, n_uniq=43
# Column V197: float64 -> float16, na_count=370316, n_uniq=13
# Column V198: float64 -> float16, na_count=370316, n_uniq=30
# Column V199: float64 -> float16, na_count=369957, n_uniq=226
# Column V200: float64 -> float16, na_count=370316, n_uniq=49
# Column V201: float64 -> float16, na_count=370316, n_uniq=49
# Column V202: float64 -> float32, na_count=369957, n_uniq=9564
# Column V203: float64 -> float32, na_count=369957, n_uniq=13941
# Column V204: float64 -> float32, na_count=369957, n_uniq=11819
# Column V205: float64 -> float32, na_count=369957, n_uniq=1980
# Column V206: float64 -> float32, na_count=369957, n_uniq=1563
# Column V207: float64 -> float32, na_count=369957, n_uniq=2892
# Column V208: float64 -> float32, na_count=370316, n_uniq=2100
# Column V209: float64 -> float32, na_count=370316, n_uniq=3244
# Column V210: float64 -> float32, na_count=370316, n_uniq=2479
# Column V211: float64 -> float32, na_count=369957, n_uniq=6541
# Column V212: float64 -> float32, na_count=369957, n_uniq=7977
# Column V213: float64 -> float32, na_count=369957, n_uniq=7441
# Column V214: float64 -> float32, na_count=369957, n_uniq=2045
# Column V215: float64 -> float32, na_count=369957, n_uniq=2509
# Column V216: float64 -> float32, na_count=369957, n_uniq=2252
# Column V217: float64 -> float16, na_count=379963, n_uniq=240
# Column V218: float64 -> float16, na_count=379963, n_uniq=292
# Column V219: float64 -> float16, na_count=379963, n_uniq=292
# Column V220: float64 -> float16, na_count=369375, n_uniq=45
# Column V221: float64 -> float16, na_count=369375, n_uniq=61
# Column V222: float64 -> float16, na_count=369375, n_uniq=293
# Column V223: float64 -> float16, na_count=379963, n_uniq=10
# Column V224: float64 -> float16, na_count=379963, n_uniq=51
# Column V225: float64 -> float16, na_count=379963, n_uniq=22
# Column V226: float64 -> float16, na_count=379963, n_uniq=83
# Column V227: float64 -> float16, na_count=369375, n_uniq=41
# Column V228: float64 -> float16, na_count=379963, n_uniq=240
# Column V229: float64 -> float16, na_count=379963, n_uniq=263
# Column V230: float64 -> float16, na_count=379963, n_uniq=263
# Column V231: float64 -> float16, na_count=379963, n_uniq=240
# Column V232: float64 -> float16, na_count=379963, n_uniq=292
# Column V233: float64 -> float16, na_count=379963, n_uniq=292
# Column V234: float64 -> float16, na_count=369375, n_uniq=309
# Column V235: float64 -> float16, na_count=379963, n_uniq=17
# Column V236: float64 -> float16, na_count=379963, n_uniq=49
# Column V237: float64 -> float16, na_count=379963, n_uniq=28
# Column V238: float64 -> float16, na_count=369375, n_uniq=14
# Column V239: float64 -> float16, na_count=369375, n_uniq=14
# Column V240: float64 -> float16, na_count=379963, n_uniq=6
# Column V241: float64 -> float16, na_count=379963, n_uniq=4
# Column V242: float64 -> float16, na_count=379963, n_uniq=29
# Column V243: float64 -> float16, na_count=379963, n_uniq=45
# Column V244: float64 -> float16, na_count=379963, n_uniq=35
# Column V245: float64 -> float16, na_count=369375, n_uniq=38
# Column V246: float64 -> float16, na_count=379963, n_uniq=226
# Column V247: float64 -> float16, na_count=379963, n_uniq=12
# Column V248: float64 -> float16, na_count=379963, n_uniq=28
# Column V249: float64 -> float16, na_count=379963, n_uniq=20
# Column V250: float64 -> float16, na_count=369375, n_uniq=10
# Column V251: float64 -> float16, na_count=369375, n_uniq=13
# Column V252: float64 -> float16, na_count=379963, n_uniq=18
# Column V253: float64 -> float16, na_count=379963, n_uniq=73
# Column V254: float64 -> float16, na_count=379963, n_uniq=38
# Column V255: float64 -> float16, na_count=369375, n_uniq=35
# Column V256: float64 -> float16, na_count=369375, n_uniq=35
# Column V257: float64 -> float16, na_count=379963, n_uniq=226
# Column V258: float64 -> float16, na_count=379963, n_uniq=271
# Column V259: float64 -> float16, na_count=369375, n_uniq=58
# Column V260: float64 -> float16, na_count=379963, n_uniq=16
# Column V261: float64 -> float16, na_count=379963, n_uniq=68
# Column V262: float64 -> float16, na_count=379963, n_uniq=33
# Column V263: float64 -> float32, na_count=379963, n_uniq=9588
# Column V264: float64 -> float32, na_count=379963, n_uniq=12701
# Column V265: float64 -> float32, na_count=379963, n_uniq=11092
# Column V266: float64 -> float32, na_count=379963, n_uniq=1916
# Column V267: float64 -> float32, na_count=379963, n_uniq=3366
# Column V268: float64 -> float32, na_count=379963, n_uniq=2460
# Column V269: float64 -> float32, na_count=379963, n_uniq=155
# Column V270: float64 -> float32, na_count=369375, n_uniq=1982
# Column V271: float64 -> float32, na_count=369375, n_uniq=2615
# Column V272: float64 -> float32, na_count=369375, n_uniq=2189
# Column V273: float64 -> float32, na_count=379963, n_uniq=6777
# Column V274: float64 -> float32, na_count=379963, n_uniq=7955
# Column V275: float64 -> float32, na_count=379963, n_uniq=7495
# Column V276: float64 -> float32, na_count=379963, n_uniq=1963
# Column V277: float64 -> float32, na_count=379963, n_uniq=2229
# Column V278: float64 -> float32, na_count=379963, n_uniq=2081
# Column V279: float64 -> float16, na_count=3, n_uniq=88
# Column V280: float64 -> float16, na_count=3, n_uniq=110
# Column V281: float64 -> float16, na_count=6031, n_uniq=32
# Column V282: float64 -> float16, na_count=6031, n_uniq=65
# Column V283: float64 -> float16, na_count=6031, n_uniq=70
# Column V284: float64 -> float16, na_count=3, n_uniq=10
# Column V285: float64 -> float16, na_count=3, n_uniq=92
# Column V286: float64 -> float16, na_count=3, n_uniq=8
# Column V287: float64 -> float16, na_count=3, n_uniq=33
# Column V288: float64 -> float16, na_count=6031, n_uniq=8
# Column V289: float64 -> float16, na_count=6031, n_uniq=13
# Column V290: float64 -> float16, na_count=3, n_uniq=50
# Column V291: float64 -> float16, na_count=3, n_uniq=146
# Column V292: float64 -> float16, na_count=3, n_uniq=71
# Column V293: float64 -> float16, na_count=3, n_uniq=64
# Column V294: float64 -> float16, na_count=3, n_uniq=191
# Column V295: float64 -> float16, na_count=3, n_uniq=73
# Column V296: float64 -> float16, na_count=6031, n_uniq=181
# Column V297: float64 -> float16, na_count=3, n_uniq=87
# Column V298: float64 -> float16, na_count=3, n_uniq=127
# Column V299: float64 -> float16, na_count=3, n_uniq=108
# Column V300: float64 -> float16, na_count=6031, n_uniq=16
# Column V301: float64 -> float16, na_count=6031, n_uniq=16
# Column V302: float64 -> float16, na_count=3, n_uniq=15
# Column V303: float64 -> float16, na_count=3, n_uniq=19
# Column V304: float64 -> float16, na_count=3, n_uniq=19
# Column V305: float64 -> float16, na_count=3, n_uniq=3
# Column V306: float64 -> float32, na_count=3, n_uniq=13261
# Column V307: float64 -> float32, na_count=3, n_uniq=29593
# Column V308: float64 -> float32, na_count=3, n_uniq=18942
# Column V309: float64 -> float32, na_count=3, n_uniq=3205
# Column V310: float64 -> float32, na_count=3, n_uniq=15385
# Column V311: float64 -> float32, na_count=3, n_uniq=2313
# Column V312: float64 -> float32, na_count=3, n_uniq=6439
# Column V313: float64 -> float32, na_count=6031, n_uniq=4113
# Column V314: float64 -> float32, na_count=6031, n_uniq=9052
# Column V315: float64 -> float32, na_count=6031, n_uniq=5377
# Column V316: float64 -> float32, na_count=3, n_uniq=7561
# Column V317: float64 -> float32, na_count=3, n_uniq=11280
# Column V318: float64 -> float32, na_count=3, n_uniq=9490
# Column V319: float64 -> float32, na_count=3, n_uniq=4904
# Column V320: float64 -> float32, na_count=3, n_uniq=6480
# Column V321: float64 -> float32, na_count=3, n_uniq=5616
# Column V322: float64 -> float16, na_count=430260, n_uniq=88
# Column V323: float64 -> float16, na_count=430260, n_uniq=130
# Column V324: float64 -> float16, na_count=430260, n_uniq=110
# Column V325: float64 -> float16, na_count=430260, n_uniq=10
# Column V326: float64 -> float16, na_count=430260, n_uniq=46
# Column V327: float64 -> float16, na_count=430260, n_uniq=33
# Column V328: float64 -> float16, na_count=430260, n_uniq=87
# Column V329: float64 -> float16, na_count=430260, n_uniq=127
# Column V330: float64 -> float16, na_count=430260, n_uniq=108
# Column V331: float64 -> float32, na_count=430260, n_uniq=606
# Column V332: float64 -> float32, na_count=430260, n_uniq=1452
# Column V333: float64 -> float32, na_count=430260, n_uniq=956
# Column V334: float64 -> float32, na_count=430260, n_uniq=164
# Column V335: float64 -> float32, na_count=430260, n_uniq=781
# Column V336: float64 -> float32, na_count=430260, n_uniq=370
# Column V337: float64 -> float32, na_count=430260, n_uniq=329
# Column V338: float64 -> float32, na_count=430260, n_uniq=571
# Column V339: float64 -> float32, na_count=430260, n_uniq=448
# Column DT: float64 -> int16, na_count=0, n_uniq=183
# Column D1achr: float64 -> float16, na_count=6031, n_uniq=822
# Column D2achr: float64 -> float16, na_count=234769, n_uniq=822
# Column D4achr: float64 -> float16, na_count=76851, n_uniq=1068
# Column D6achr: float64 -> float16, na_count=381908, n_uniq=1067
# Column D10achr: float64 -> float16, na_count=12545, n_uniq=1079
# Column D11achr: float64 -> float16, na_count=176518, n_uniq=888
# Column D12achr: float64 -> float16, na_count=437437, n_uniq=866
# Column D13achr: float64 -> float16, na_count=383307, n_uniq=759
# Column D14achr: float64 -> float16, na_count=391497, n_uniq=1033
# Column D15achr: float64 -> float16, na_count=12069, n_uniq=1084
# Mem. usage decreased from 1872.06 Mb to 810.43 Mb (56.7% reduction)

# %%
##### Saving both DataFrames into binary files to speed next uploadings.

print('Saving datasets...')
train.to_pickle('train_mred.pkl')
print('Train has been saved... (1/2)')
test.to_pickle('test_mred.pkl')
print('Test has been saved... (2/2)')
print('Done!')
# Out:
# Saving datasets...
# Train has been saved... (1/2)
# Test has been saved... (2/2)
# Done!
